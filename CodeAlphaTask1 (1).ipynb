# %%
# !pip install requests beautifulsoup4 pandas matplotlib
# Out:
# Requirement already satisfied: requests in c:\users\alha\anaconda3\lib\site-packages (2.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\alha\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\alha\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\alha\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alha\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alha\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\alha\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\alha\anaconda3\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alha\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alha\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alha\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alha\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alha\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alha\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\alha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://books.toscrape.com/"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
books = soup.find_all("article", class_="product_pod")

print(len(books))
# Out:
# 20

# %%
book = books[0]

title = book.h3.a["title"]

print(title)
# Out:
# A Light in the Attic

# %%
price = book.find("p", class_="price_color").text

print(price)
# Out:
# Â£51.77

# %%
availability = book.find("p", class_="instock availability").text.strip()

print(availability)
# Out:
# In stock

# %%
rating = book.find("p", class_="star-rating")["class"][1]

print(rating)
# Out:
# Three

# %%
link = book.h3.a["href"]

print(link)
# Out:
# catalogue/a-light-in-the-attic_1000/index.html

# %%
data = []

for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text
    availability = book.find(
        "p", class_="instock availability"
    ).text.strip()
    rating = book.find("p", class_="star-rating")["class"][1]
    link = book.h3.a["href"]

    data.append([
        title,
        price,
        availability,
        rating,
        link
    ])

# %%
df = pd.DataFrame(
    data,
    columns=[
        "Book Title",
        "Price",
        "Availability",
        "Rating",
        "Book URL"
    ]
)

df.head()
# Out:
#                               Book Title    Price Availability Rating  \
# 0                   A Light in the Attic  Â£51.77     In stock  Three
# 1                     Tipping the Velvet  Â£53.74     In stock    One
# 2                             Soumission  Â£50.10     In stock    One
# 3                          Sharp Objects  Â£47.82     In stock   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23     In stock   Five
#
#                                             Book URL
# 0     catalogue/a-light-in-the-attic_1000/index.html
# 1        catalogue/tipping-the-velvet_999/index.html
# 2                catalogue/soumission_998/index.html
# 3             catalogue/sharp-objects_997/index.html
# 4  catalogue/sapiens-a-brief-history-of-humankind...

# %%
print(df.shape)
# Out:
# (20, 5)

# %%
print(df.columns)
# Out:
# Index(['Book Title', 'Price', 'Availability', 'Rating', 'Book URL'], dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Book Title      0
# Price           0
# Availability    0
# Rating          0
# Book URL        0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

df["Rating"] = df["Rating"].map(rating_map)

# %%
top_10 = df.sort_values(
    by="Price",
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))

plt.bar(
    top_10["Book Title"],
    top_10["Price"]
)

plt.xticks(rotation=90)

plt.xlabel("Book Title")
plt.ylabel("Price (£)")
plt.title("Top 10 Most Expensive Books")

plt.tight_layout()

plt.show()
# Out:
# C:\Users\alha\AppData\Local\Temp\ipykernel_5464\2424989057.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df.to_csv(
    "books_scraped_dataset.csv",
    index=False
)

# %%
df = pd.read_csv("books_scraped_dataset.csv")

print(df.head())
# Out:
#                               Book Title    Price Availability  Rating  \
# 0                   A Light in the Attic  Â£51.77     In stock       3
# 1                     Tipping the Velvet  Â£53.74     In stock       1
# 2                             Soumission  Â£50.10     In stock       1
# 3                          Sharp Objects  Â£47.82     In stock       4
# 4  Sapiens: A Brief History of Humankind  Â£54.23     In stock       5
#
#                                             Book URL
# 0     catalogue/a-light-in-the-attic_1000/index.html
# 1        catalogue/tipping-the-velvet_999/index.html
# 2                catalogue/soumission_998/index.html
# 3             catalogue/sharp-objects_997/index.html
# 4  catalogue/sapiens-a-brief-history-of-humankind...

# %%
data = []

for page in range(1, 6):

    url = f"https://books.toscrape.com/catalogue/page-{page}.html"

    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")

    for book in books:

        title = book.h3.a["title"]

        price = book.find(
            "p",
            class_="price_color"
        ).text

        availability = book.find(
            "p",
            class_="instock availability"
        ).text.strip()

        rating = book.find(
            "p",
            class_="star-rating"
        )["class"][1]

        link = book.h3.a["href"]

        data.append([
            title,
            price,
            availability,
            rating,
            link
        ])

# %%
df = pd.DataFrame(
    data,
    columns=[
        "Book Title",
        "Price",
        "Availability",
        "Rating",
        "Book URL"
    ]
)

print(df.shape)
# Out:
# (100, 5)

# %%
df.to_csv(
    "books_web_scraped_dataset.csv",
    index=False
)
